# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the CSV file
csv_file_path = '../data/train_even.csv'  # Replace with your actual file path
df = pd.read_csv(csv_file_path)

# %%
# Check the unique value counts for a specific column
column_name = 'label'  # Replace with the actual column name
value_counts = df[column_name].value_counts()

# %%
# Plot the value distribution using seaborn for better visualization
plt.figure(figsize=(10, 6))
sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')

# Add labels and title
plt.xlabel(f'{column_name} Values', fontsize=12)
plt.ylabel('Counts', fontsize=12)
plt.title(f'Value Distribution in {column_name}', fontsize=16)

# Rotate x labels for better readability if necessary
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_338534/2216935892.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')

# %%
# 특정 값을 가진 행 필터링 (예: 'some_value'라는 값을 가진 row 필터링)
column_name = 'label'
filtered_rows = df[(df[column_name] >= 4.4) & (df[column_name] < 5.0)]


# 변경된 데이터프레임 확인
print(filtered_rows[['sentence_1','sentence_2']])
# Out:
#                                               sentence_1  \
# 25                        금융워원회의 공모주 개인 배정 축소(폐지)를 막아주세요
# 26                                           지금 아주 만족해요.
# 37                            의료계 환경 개선 및 경찰소방공무원 지원해주세요
# 72        저도 클라이밍 너무 배우고 싶은데, 기회가 된다면 함께 하면 좋을 것 같습니다!!!
# 121    [제발]이명박 개별청원하지 마시고 추천수로 정렬하셔서 3만명대 나오는 청원에 참여하...
# ...                                                  ...
# 11983                                         소개가 늦었습니다.
# 11984                           국민건강보험공단 카드결제 수수료 탈세인가요?
# 11985                                        진짜 재밌게 봤음!!
# 11986                                        다시한번보고싶은영화!
# 11987                                       모두들 수고하셨습니다.
#
#                                               sentence_2
# 25                        금융감독원의 공모주 개인배분 축소(폐지)를 막아주세요.
# 26                                         지금은 매우 만족합니다.
# 37                            의료환경 개선과 경찰·소방관 지원 부탁드립니다.
# ...
