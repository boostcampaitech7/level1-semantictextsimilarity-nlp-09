# %%
import pandas as pd

df = pd.read_csv('../team_data/SR_train_5.csv')

# id 값이 2개 이상인 것들 필터링
duplicated_ids = df[df['id'].duplicated(keep=False)]

duplicated_ids.sort_values(by='id').head(50)

# row = df[df['id'] == 'boostcamp-sts-v1-train-9314']
# row
# Out:
#                               id            source  \
# 2     boostcamp-sts-v1-train-002  petition-sampled
# 9327  boostcamp-sts-v1-train-002  petition-sampled
# 9326  boostcamp-sts-v1-train-002  petition-sampled
# 9325  boostcamp-sts-v1-train-002  petition-sampled
# 9324  boostcamp-sts-v1-train-002  petition-sampled
# 9     boostcamp-sts-v1-train-009  petition-sampled
# 9329  boostcamp-sts-v1-train-009  petition-sampled
# 9328  boostcamp-sts-v1-train-009  petition-sampled
# 11    boostcamp-sts-v1-train-011      nsmc-sampled
# 9331  boostcamp-sts-v1-train-011      nsmc-sampled
# 9330  boostcamp-sts-v1-train-011      nsmc-sampled
# 16    boostcamp-sts-v1-train-016     slack-sampled
# 9332  boostcamp-sts-v1-train-016     slack-sampled
# 9333  boostcamp-sts-v1-train-016     slack-sampled
# 9337  boostcamp-sts-v1-train-017      petition-rtt
# 9338  boostcamp-sts-v1-train-017      petition-rtt
# 9339  boostcamp-sts-v1-train-017      petition-rtt
# ...

# %%
duplicated_ids = df[df['id'].duplicated(keep=False)]['id'].unique()

print(duplicated_ids)
# Out:
# ['boostcamp-sts-v1-train-002' 'boostcamp-sts-v1-train-009'
#  'boostcamp-sts-v1-train-011' ... 'boostcamp-sts-v1-train-9306'
#  'boostcamp-sts-v1-train-9314' 'boostcamp-sts-v1-train-9318']
