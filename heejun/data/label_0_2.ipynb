# %%
import pandas as pd

valid = pd.read_csv('dev.csv')
valid.hist(bins=51)
# Out:
# array([[<Axes: title={'center': 'label'}>,
#         <Axes: title={'center': 'binary-label'}>]], dtype=object)

# %%
output_valid_1 = pd.read_csv('/data/ephemeral/home/heejun/STS/models/output_valid_1-0.933421_klue-roberta-large.pt.csv')
output_valid_2 = pd.read_csv('/data/ephemeral/home/heejun/STS/models/output_valid_2-0.933421_klue-roberta-large.pt.csv')

output_valid_1.hist(bins=51), output_valid_2.hist(bins=51)
# Out:
# (array([[<Axes: title={'center': 'target'}>]], dtype=object),
#  array([[<Axes: title={'center': 'target'}>]], dtype=object))
